# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

import catboost as cb
import xgboost as xgb
from bayes_opt import BayesianOptimization
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score
from sklearn.pipeline import Pipeline

# %% [markdown]
# # ф-ии

# %%
# CatBoost
def catboost_base(x, x_val, y, y_val):
    cb_params = {
    "n_estimators": 2000,
    "learning_rate": 0.001,
    "loss_function": "Logloss",
    "eval_metric": "AUC",
    "task_type": "CPU",
    "max_bin": 20,
    "verbose": False,
    "max_depth": 6,
    "l2_leaf_reg": 10,
    "early_stopping_rounds": 50,
    "thread_count": 6,
    "random_seed": 42
    }

    model = cb.CatBoostClassifier(**cb_params)
    model.fit(x, y,
        )
    y_pred = model.predict(x_val)
    print("roc_auc_score: ",roc_auc_score(y_val, y_pred))
    print("confusion_matrix: ",confusion_matrix(y_val, y_pred))
    print("accuracy_score: ",accuracy_score(y_val, y_pred))

# %%
# XGBoost
def xgb_base(x, x_val, y, y_val):

    params = {
    "booster": "gbtree",
    "eval_metric": "auc",
    "objective": "binary:logistic",
    "learning_rate": 0.01,
    "nthread": 6,
    "seed": 27
    }

    dtrain = xgb.DMatrix(
    x, y
    )
    dvalid = xgb.DMatrix(
    x_val, y_val
    )

    model = xgb.train(
        params=params,
        dtrain=dtrain,
        evals=[(dtrain, "dtrain"), (dvalid, "dvalid")],
        early_stopping_rounds=25,
        num_boost_round=1000,
        verbose_eval=10,
        maximize=True,
    )

# %%
def forest_base(x, x_val, y, y_val):
    model = RandomForestClassifier(
    n_estimators=250, max_depth=8, n_jobs=6, random_state=27
    )
    model.fit(x, y)
    y_pred = model.predict(x_val)
    print("roc_auc_score: ",roc_auc_score(y_val, y_pred))
    print("confusion_matrix: ",confusion_matrix(y_val, y_pred))
    print("accuracy_score: ",accuracy_score(y_val, y_pred))

# %% [markdown]
# # Чтение данных

# %%
path = "./data"
print(os.listdir(path))

train = pd.read_csv(f"{path}/train_new.csv")
train.columns = train.columns.str.lower()
test = pd.read_csv(f"{path}/test.csv")
test.columns = test.columns.str.lower()

print("train.shape = {} rows, {} cols".format(*train.shape))
print("test.shape = {} rows, {} cols".format(*test.shape))
# Out:
# ['greeks.csv', 'sample_submission.csv', 'test.csv', 'train.csv', 'train_new.csv']
# train.shape = 617 rows, 57 cols
# test.shape = 5 rows, 57 cols

# %%
for i in train.columns:
    if i != "id":
        train[i] = train[i].fillna(train[i].median())

# %%
train.isna().sum()
# Out:
# ab         0
# af         0
# ah         0
# am         0
# ar         0
# ax         0
# ay         0
# az         0
# bc         0
# bd         0
# bn         0
# bp         0
# bq         0
# br         0
# bz         0
# cb         0
# cc         0
# cd         0
# cf         0
# ch         0
# cl         0
# cr         0
# cs         0
# cu         0
# cw         0
# da         0
# de         0
# df         0
# dh         0
# di         0
# dl         0
# dn         0
# du         0
# dv         0
# dy         0
# eb         0
# ee         0
# eg         0
# eh         0
# el         0
# ep         0
# eu         0
# fc         0
# fd         0
# fe         0
# fi         0
# fl         0
# fr         0
# fs         0
# gb         0
# ge         0
# gf         0
# gh         0
# gi         0
# gl         0
# class      0
# ej_freq    0
# dtype: int64

# %% [markdown]
# # train test split

# %%
train.dtypes[train.dtypes == "object"]
# Out:
# Series([], dtype: object)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train.drop( "class", axis=1), train["class"], test_size = 0.2)
x_train.shape, x_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((493, 56), (124, 56), (493,), (124,))

# %% [markdown]
# # Baseline XGBoost-classifier

# %%
xgb_base(x_train, x_valid, y_train, y_valid)
# Out:
# [0]	dtrain-auc:0.95183	dvalid-auc:0.88083
# [10]	dtrain-auc:0.95468	dvalid-auc:0.88313
# [20]	dtrain-auc:0.95490	dvalid-auc:0.88333
# [30]	dtrain-auc:0.98179	dvalid-auc:0.92292
# [40]	dtrain-auc:0.98405	dvalid-auc:0.92875
# [50]	dtrain-auc:0.98695	dvalid-auc:0.92375
# [60]	dtrain-auc:0.98866	dvalid-auc:0.91792
# [62]	dtrain-auc:0.98881	dvalid-auc:0.91625

# %% [markdown]
# # Baseline RandomForestClassifier

# %%
forest_base(x_train, x_valid, y_train, y_valid)
# Out:
# roc_auc_score:  0.7916666666666667
# confusion_matrix:  [[100   0]
#  [ 10  14]]
# accuracy_score:  0.9193548387096774

# %% [markdown]
# # Baseline CatBoostClassifier

# %%
catboost_base(x_train, x_valid, y_train, y_valid)
# Out:
# 0:	total: 149ms	remaining: 4m 57s
# 10:	total: 203ms	remaining: 36.6s
# 20:	total: 228ms	remaining: 21.5s
# 30:	total: 252ms	remaining: 16s
# 40:	total: 275ms	remaining: 13.1s
# 50:	total: 296ms	remaining: 11.3s
# 60:	total: 317ms	remaining: 10.1s
# 70:	total: 339ms	remaining: 9.21s
# 80:	total: 365ms	remaining: 8.65s
# 90:	total: 386ms	remaining: 8.11s
# 100:	total: 407ms	remaining: 7.66s
# 110:	total: 428ms	remaining: 7.28s
# 120:	total: 449ms	remaining: 6.97s
# 130:	total: 470ms	remaining: 6.71s
# 140:	total: 491ms	remaining: 6.47s
# 150:	total: 512ms	remaining: 6.27s
# 160:	total: 532ms	remaining: 6.08s
# 170:	total: 553ms	remaining: 5.92s
# 180:	total: 578ms	remaining: 5.81s
# 190:	total: 600ms	remaining: 5.68s
# 200:	total: 622ms	remaining: 5.57s
# 210:	total: 643ms	remaining: 5.45s
# 220:	total: 663ms	remaining: 5.34s
# 230:	total: 684ms	remaining: 5.24s
# 240:	total: 704ms	remaining: 5.14s
# 250:	total: 724ms	remaining: 5.04s
# 260:	total: 745ms	remaining: 4.96s
# 270:	total: 765ms	remaining: 4.88s
# 280:	total: 789ms	remaining: 4.83s
# 290:	total: 810ms	remaining: 4.75s
# 300:	total: 830ms	remaining: 4.68s
# 310:	total: 851ms	remaining: 4.62s
# 320:	total: 872ms	remaining: 4.56s
# 330:	total: 893ms	remaining: 4.5s
# 340:	total: 913ms	remaining: 4.44s
# 350:	total: 935ms	remaining: 4.39s
# 360:	total: 956ms	remaining: 4.34s
# 370:	total: 977ms	remaining: 4.29s
# 380:	total: 1000ms	remaining: 4.25s
# 390:	total: 1.02s	remaining: 4.2s
# 400:	total: 1.04s	remaining: 4.16s
# 410:	total: 1.06s	remaining: 4.11s
# 420:	total: 1.08s	remaining: 4.07s
# 430:	total: 1.1s	remaining: 4.02s
# 440:	total: 1.13s	remaining: 3.98s
# 450:	total: 1.15s	remaining: 3.94s
# 460:	total: 1.17s	remaining: 3.9s
# 470:	total: 1.19s	remaining: 3.87s
# 480:	total: 1.21s	remaining: 3.83s
# 490:	total: 1.23s	remaining: 3.79s
# 500:	total: 1.25s	remaining: 3.75s
# 510:	total: 1.27s	remaining: 3.71s
# 520:	total: 1.3s	remaining: 3.68s
# 530:	total: 1.32s	remaining: 3.64s
# 540:	total: 1.34s	remaining: 3.61s
# 550:	total: 1.36s	remaining: 3.57s
# 560:	total: 1.38s	remaining: 3.54s
# 570:	total: 1.4s	remaining: 3.51s
# 580:	total: 1.42s	remaining: 3.47s
# 590:	total: 1.44s	remaining: 3.44s
# 600:	total: 1.46s	remaining: 3.41s
# 610:	total: 1.48s	remaining: 3.38s
# 620:	total: 1.5s	remaining: 3.34s
# 630:	total: 1.53s	remaining: 3.31s
# 640:	total: 1.55s	remaining: 3.28s
# 650:	total: 1.57s	remaining: 3.25s
# 660:	total: 1.59s	remaining: 3.22s
# 670:	total: 1.61s	remaining: 3.19s
# 680:	total: 1.63s	remaining: 3.16s
# 690:	total: 1.65s	remaining: 3.13s
# 700:	total: 1.67s	remaining: 3.1s
# 710:	total: 1.69s	remaining: 3.07s
# 720:	total: 1.71s	remaining: 3.04s
# 730:	total: 1.73s	remaining: 3.01s
# 740:	total: 1.76s	remaining: 2.98s
# 750:	total: 1.78s	remaining: 2.95s
# 760:	total: 1.8s	remaining: 2.93s
# 770:	total: 1.82s	remaining: 2.9s
# 780:	total: 1.84s	remaining: 2.88s
# 790:	total: 1.86s	remaining: 2.85s
# 800:	total: 1.88s	remaining: 2.82s
# 810:	total: 1.9s	remaining: 2.79s
# 820:	total: 1.92s	remaining: 2.76s
# 830:	total: 1.94s	remaining: 2.73s
# 840:	total: 1.97s	remaining: 2.71s
# 850:	total: 1.99s	remaining: 2.68s
# 860:	total: 2.01s	remaining: 2.66s
# 870:	total: 2.03s	remaining: 2.63s
# 880:	total: 2.05s	remaining: 2.61s
# 890:	total: 2.07s	remaining: 2.58s
# 900:	total: 2.09s	remaining: 2.55s
# 910:	total: 2.11s	remaining: 2.53s
# 920:	total: 2.13s	remaining: 2.5s
# 930:	total: 2.15s	remaining: 2.47s
# 940:	total: 2.17s	remaining: 2.45s
# 950:	total: 2.2s	remaining: 2.42s
# 960:	total: 2.22s	remaining: 2.4s
# 970:	total: 2.24s	remaining: 2.37s
# 980:	total: 2.26s	remaining: 2.35s
# 990:	total: 2.28s	remaining: 2.32s
# 1000:	total: 2.3s	remaining: 2.3s
# 1010:	total: 2.32s	remaining: 2.27s
# 1020:	total: 2.34s	remaining: 2.25s
# 1030:	total: 2.37s	remaining: 2.22s
# 1040:	total: 2.38s	remaining: 2.2s
# 1050:	total: 2.41s	remaining: 2.17s
# 1060:	total: 2.43s	remaining: 2.15s
# 1070:	total: 2.45s	remaining: 2.13s
# 1080:	total: 2.47s	remaining: 2.1s
# 1090:	total: 2.49s	remaining: 2.08s
# 1100:	total: 2.51s	remaining: 2.05s
# 1110:	total: 2.53s	remaining: 2.03s
# 1120:	total: 2.56s	remaining: 2s
# 1130:	total: 2.58s	remaining: 1.98s
# 1140:	total: 2.6s	remaining: 1.96s
# 1150:	total: 2.62s	remaining: 1.93s
# 1160:	total: 2.64s	remaining: 1.91s
# 1170:	total: 2.66s	remaining: 1.89s
# 1180:	total: 2.69s	remaining: 1.86s
# 1190:	total: 2.71s	remaining: 1.84s
# 1200:	total: 2.73s	remaining: 1.81s
# 1210:	total: 2.75s	remaining: 1.79s
# 1220:	total: 2.77s	remaining: 1.77s
# 1230:	total: 2.79s	remaining: 1.74s
# 1240:	total: 2.81s	remaining: 1.72s
# 1250:	total: 2.83s	remaining: 1.7s
# 1260:	total: 2.85s	remaining: 1.67s
# 1270:	total: 2.87s	remaining: 1.65s
# 1280:	total: 2.9s	remaining: 1.63s
# 1290:	total: 2.92s	remaining: 1.6s
# 1300:	total: 2.94s	remaining: 1.58s
# 1310:	total: 2.96s	remaining: 1.55s
# 1320:	total: 2.98s	remaining: 1.53s
# 1330:	total: 3s	remaining: 1.51s
# 1340:	total: 3.02s	remaining: 1.48s
# 1350:	total: 3.04s	remaining: 1.46s
# 1360:	total: 3.06s	remaining: 1.44s
# 1370:	total: 3.08s	remaining: 1.42s
# 1380:	total: 3.1s	remaining: 1.39s
# 1390:	total: 3.13s	remaining: 1.37s
# 1400:	total: 3.15s	remaining: 1.34s
# 1410:	total: 3.17s	remaining: 1.32s
# 1420:	total: 3.19s	remaining: 1.3s
# 1430:	total: 3.21s	remaining: 1.28s
# 1440:	total: 3.23s	remaining: 1.25s
# 1450:	total: 3.25s	remaining: 1.23s
# 1460:	total: 3.27s	remaining: 1.21s
# 1470:	total: 3.29s	remaining: 1.18s
# 1480:	total: 3.31s	remaining: 1.16s
# 1490:	total: 3.33s	remaining: 1.14s
# 1500:	total: 3.36s	remaining: 1.11s
# 1510:	total: 3.38s	remaining: 1.09s
# 1520:	total: 3.4s	remaining: 1.07s
# 1530:	total: 3.42s	remaining: 1.05s
# 1540:	total: 3.44s	remaining: 1.02s
# 1550:	total: 3.46s	remaining: 1s
# 1560:	total: 3.48s	remaining: 979ms
# 1570:	total: 3.5s	remaining: 957ms
# 1580:	total: 3.52s	remaining: 934ms
# 1590:	total: 3.54s	remaining: 911ms
# 1600:	total: 3.56s	remaining: 888ms
# 1610:	total: 3.58s	remaining: 866ms
# 1620:	total: 3.61s	remaining: 843ms
# 1630:	total: 3.63s	remaining: 821ms
# 1640:	total: 3.65s	remaining: 799ms
# 1650:	total: 3.67s	remaining: 776ms
# 1660:	total: 3.69s	remaining: 754ms
# 1670:	total: 3.71s	remaining: 731ms
# 1680:	total: 3.73s	remaining: 709ms
# 1690:	total: 3.75s	remaining: 686ms
# 1700:	total: 3.77s	remaining: 663ms
# 1710:	total: 3.79s	remaining: 641ms
# 1720:	total: 3.81s	remaining: 618ms
# 1730:	total: 3.84s	remaining: 596ms
# 1740:	total: 3.86s	remaining: 574ms
# 1750:	total: 3.88s	remaining: 552ms
# 1760:	total: 3.9s	remaining: 529ms
# 1770:	total: 3.92s	remaining: 507ms
# 1780:	total: 3.94s	remaining: 485ms
# 1790:	total: 3.96s	remaining: 462ms
# 1800:	total: 3.98s	remaining: 440ms
# 1810:	total: 4s	remaining: 418ms
# 1820:	total: 4.02s	remaining: 396ms
# 1830:	total: 4.05s	remaining: 374ms
# 1840:	total: 4.07s	remaining: 351ms
# 1850:	total: 4.09s	remaining: 329ms
# 1860:	total: 4.11s	remaining: 307ms
# 1870:	total: 4.13s	remaining: 285ms
# 1880:	total: 4.15s	remaining: 263ms
# 1890:	total: 4.17s	remaining: 241ms
# 1900:	total: 4.19s	remaining: 218ms
# 1910:	total: 4.21s	remaining: 196ms
# 1920:	total: 4.24s	remaining: 174ms
# 1930:	total: 4.26s	remaining: 152ms
# 1940:	total: 4.28s	remaining: 130ms
# 1950:	total: 4.3s	remaining: 108ms
# 1960:	total: 4.32s	remaining: 85.9ms
# 1970:	total: 4.34s	remaining: 63.9ms
# 1980:	total: 4.36s	remaining: 41.8ms
# 1990:	total: 4.38s	remaining: 19.8ms
# 1999:	total: 4.4s	remaining: 0us
# roc_auc_score:  0.8491666666666667
# confusion_matrix:  [[99  1]
#  [ 7 17]]
# accuracy_score:  0.9354838709677419

# %% [markdown]
# # Обучение с удалением пропусков

# %%
path = "./data"
print(os.listdir(path))

train = pd.read_csv(f"{path}/train_new.csv")
train.columns = train.columns.str.lower()
test = pd.read_csv(f"{path}/test.csv")
test.columns = test.columns.str.lower()

print("train.shape = {} rows, {} cols".format(*train.shape))
print("test.shape = {} rows, {} cols".format(*test.shape))
# Out:
# ['greeks.csv', 'sample_submission.csv', 'test.csv', 'train.csv', 'train_new.csv']
# train.shape = 617 rows, 57 cols
# test.shape = 5 rows, 57 cols

# %%
train = train.dropna()

# %% [markdown]
# ## train_test_split

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train.drop( "class", axis=1), train["class"], test_size = 0.2)
x_train.shape, x_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((438, 56), (110, 56), (438,), (110,))

# %% [markdown]
# ## baseline xgb

# %%
xgb_base(x_train, x_valid, y_train, y_valid)
# Out:
# [0]	dtrain-auc:0.97813	dvalid-auc:0.84012
# [10]	dtrain-auc:0.97999	dvalid-auc:0.83527
# [20]	dtrain-auc:0.98059	dvalid-auc:0.83891
# [30]	dtrain-auc:0.98620	dvalid-auc:0.87597
# [40]	dtrain-auc:0.98714	dvalid-auc:0.87670
# [50]	dtrain-auc:0.98780	dvalid-auc:0.88711
# [60]	dtrain-auc:0.98839	dvalid-auc:0.90795
# [70]	dtrain-auc:0.99204	dvalid-auc:0.91085
# [80]	dtrain-auc:0.99156	dvalid-auc:0.91860
# [90]	dtrain-auc:0.99209	dvalid-auc:0.92878
# [100]	dtrain-auc:0.99434	dvalid-auc:0.93847
# [110]	dtrain-auc:0.99526	dvalid-auc:0.94089
# [120]	dtrain-auc:0.99623	dvalid-auc:0.94186
# [130]	dtrain-auc:0.99708	dvalid-auc:0.94380
# [140]	dtrain-auc:0.99786	dvalid-auc:0.94816
# [150]	dtrain-auc:0.99804	dvalid-auc:0.94961
# [160]	dtrain-auc:0.99833	dvalid-auc:0.95252
# [170]	dtrain-auc:0.99865	dvalid-auc:0.95446
# [180]	dtrain-auc:0.99890	dvalid-auc:0.95252
# [190]	dtrain-auc:0.99922	dvalid-auc:0.95349
# [198]	dtrain-auc:0.99932	dvalid-auc:0.95349

# %% [markdown]
# ## RandomForestClassifier

# %%
forest_base(x_train, x_valid, y_train, y_valid)
# Out:
# roc_auc_score:  0.8275193798449612
# confusion_matrix:  [[85  1]
#  [ 8 16]]
# accuracy_score:  0.9181818181818182

# %% [markdown]
# ## catboost

# %%
catboost_base(x_train, x_valid, y_train, y_valid)
# Out:
# 0:	total: 4.25ms	remaining: 8.51s
# 10:	total: 32.4ms	remaining: 5.86s
# 20:	total: 60.2ms	remaining: 5.67s
# 30:	total: 87.4ms	remaining: 5.55s
# 40:	total: 110ms	remaining: 5.23s
# 50:	total: 135ms	remaining: 5.14s
# 60:	total: 156ms	remaining: 4.96s
# 70:	total: 178ms	remaining: 4.83s
# 80:	total: 198ms	remaining: 4.68s
# 90:	total: 219ms	remaining: 4.6s
# 100:	total: 244ms	remaining: 4.58s
# 110:	total: 264ms	remaining: 4.49s
# 120:	total: 284ms	remaining: 4.41s
# 130:	total: 304ms	remaining: 4.34s
# 140:	total: 324ms	remaining: 4.27s
# 150:	total: 346ms	remaining: 4.23s
# 160:	total: 365ms	remaining: 4.17s
# 170:	total: 386ms	remaining: 4.12s
# 180:	total: 405ms	remaining: 4.07s
# 190:	total: 426ms	remaining: 4.04s
# 200:	total: 447ms	remaining: 4s
# 210:	total: 466ms	remaining: 3.95s
# 220:	total: 485ms	remaining: 3.91s
# 230:	total: 505ms	remaining: 3.87s
# 240:	total: 525ms	remaining: 3.83s
# 250:	total: 547ms	remaining: 3.81s
# 260:	total: 567ms	remaining: 3.78s
# 270:	total: 587ms	remaining: 3.74s
# 280:	total: 606ms	remaining: 3.71s
# 290:	total: 629ms	remaining: 3.69s
# 300:	total: 649ms	remaining: 3.66s
# 310:	total: 669ms	remaining: 3.63s
# 320:	total: 689ms	remaining: 3.6s
# 330:	total: 709ms	remaining: 3.57s
# 340:	total: 728ms	remaining: 3.54s
# 350:	total: 751ms	remaining: 3.53s
# 360:	total: 770ms	remaining: 3.5s
# 370:	total: 790ms	remaining: 3.47s
# 380:	total: 810ms	remaining: 3.44s
# 390:	total: 832ms	remaining: 3.42s
# 400:	total: 853ms	remaining: 3.4s
# 410:	total: 873ms	remaining: 3.38s
# 420:	total: 893ms	remaining: 3.35s
# 430:	total: 913ms	remaining: 3.33s
# 440:	total: 935ms	remaining: 3.31s
# 450:	total: 956ms	remaining: 3.28s
# 460:	total: 979ms	remaining: 3.27s
# 470:	total: 999ms	remaining: 3.24s
# 480:	total: 1.02s	remaining: 3.22s
# 490:	total: 1.04s	remaining: 3.2s
# 500:	total: 1.06s	remaining: 3.18s
# 510:	total: 1.08s	remaining: 3.16s
# 520:	total: 1.11s	remaining: 3.14s
# 530:	total: 1.13s	remaining: 3.12s
# 540:	total: 1.15s	remaining: 3.1s
# 550:	total: 1.17s	remaining: 3.08s
# 560:	total: 1.2s	remaining: 3.07s
# 570:	total: 1.22s	remaining: 3.04s
# 580:	total: 1.24s	remaining: 3.02s
# 590:	total: 1.26s	remaining: 3s
# 600:	total: 1.28s	remaining: 2.97s
# 610:	total: 1.3s	remaining: 2.95s
# 620:	total: 1.32s	remaining: 2.92s
# 630:	total: 1.34s	remaining: 2.9s
# 640:	total: 1.36s	remaining: 2.88s
# 650:	total: 1.38s	remaining: 2.86s
# 660:	total: 1.41s	remaining: 2.86s
# 670:	total: 1.43s	remaining: 2.84s
# 680:	total: 1.45s	remaining: 2.81s
# 690:	total: 1.47s	remaining: 2.79s
# 700:	total: 1.49s	remaining: 2.77s
# 710:	total: 1.51s	remaining: 2.75s
# 720:	total: 1.53s	remaining: 2.72s
# 730:	total: 1.55s	remaining: 2.7s
# 740:	total: 1.58s	remaining: 2.68s
# 750:	total: 1.6s	remaining: 2.65s
# 760:	total: 1.62s	remaining: 2.63s
# 770:	total: 1.64s	remaining: 2.61s
# 780:	total: 1.66s	remaining: 2.59s
# 790:	total: 1.68s	remaining: 2.56s
# 800:	total: 1.7s	remaining: 2.54s
# 810:	total: 1.72s	remaining: 2.52s
# 820:	total: 1.74s	remaining: 2.5s
# 830:	total: 1.76s	remaining: 2.48s
# 840:	total: 1.78s	remaining: 2.45s
# 850:	total: 1.8s	remaining: 2.43s
# 860:	total: 1.82s	remaining: 2.41s
# 870:	total: 1.84s	remaining: 2.39s
# 880:	total: 1.86s	remaining: 2.36s
# 890:	total: 1.88s	remaining: 2.34s
# 900:	total: 1.9s	remaining: 2.32s
# 910:	total: 1.92s	remaining: 2.3s
# 920:	total: 1.94s	remaining: 2.28s
# 930:	total: 1.96s	remaining: 2.25s
# 940:	total: 1.99s	remaining: 2.23s
# 950:	total: 2.01s	remaining: 2.21s
# 960:	total: 2.03s	remaining: 2.19s
# 970:	total: 2.05s	remaining: 2.17s
# 980:	total: 2.07s	remaining: 2.15s
# 990:	total: 2.09s	remaining: 2.13s
# 1000:	total: 2.11s	remaining: 2.11s
# 1010:	total: 2.13s	remaining: 2.09s
# 1020:	total: 2.15s	remaining: 2.06s
# 1030:	total: 2.17s	remaining: 2.04s
# 1040:	total: 2.2s	remaining: 2.02s
# 1050:	total: 2.22s	remaining: 2s
# 1060:	total: 2.24s	remaining: 1.98s
# 1070:	total: 2.26s	remaining: 1.96s
# 1080:	total: 2.28s	remaining: 1.94s
# 1090:	total: 2.3s	remaining: 1.92s
# 1100:	total: 2.32s	remaining: 1.9s
# 1110:	total: 2.34s	remaining: 1.88s
# 1120:	total: 2.37s	remaining: 1.85s
# 1130:	total: 2.39s	remaining: 1.83s
# 1140:	total: 2.41s	remaining: 1.81s
# 1150:	total: 2.43s	remaining: 1.79s
# 1160:	total: 2.45s	remaining: 1.77s
# 1170:	total: 2.47s	remaining: 1.75s
# 1180:	total: 2.49s	remaining: 1.73s
# 1190:	total: 2.51s	remaining: 1.71s
# 1200:	total: 2.53s	remaining: 1.69s
# 1210:	total: 2.56s	remaining: 1.67s
# 1220:	total: 2.58s	remaining: 1.64s
# 1230:	total: 2.6s	remaining: 1.62s
# 1240:	total: 2.62s	remaining: 1.6s
# 1250:	total: 2.64s	remaining: 1.58s
# 1260:	total: 2.66s	remaining: 1.56s
# 1270:	total: 2.68s	remaining: 1.54s
# 1280:	total: 2.7s	remaining: 1.52s
# 1290:	total: 2.72s	remaining: 1.49s
# 1300:	total: 2.74s	remaining: 1.47s
# 1310:	total: 2.76s	remaining: 1.45s
# 1320:	total: 2.79s	remaining: 1.43s
# 1330:	total: 2.81s	remaining: 1.41s
# 1340:	total: 2.83s	remaining: 1.39s
# 1350:	total: 2.86s	remaining: 1.38s
# 1360:	total: 2.88s	remaining: 1.35s
# 1370:	total: 2.91s	remaining: 1.33s
# 1380:	total: 2.93s	remaining: 1.31s
# 1390:	total: 2.95s	remaining: 1.29s
# 1400:	total: 2.97s	remaining: 1.27s
# 1410:	total: 2.99s	remaining: 1.25s
# 1420:	total: 3.01s	remaining: 1.23s
# 1430:	total: 3.03s	remaining: 1.21s
# 1440:	total: 3.05s	remaining: 1.18s
# 1450:	total: 3.07s	remaining: 1.16s
# 1460:	total: 3.09s	remaining: 1.14s
# 1470:	total: 3.11s	remaining: 1.12s
# 1480:	total: 3.13s	remaining: 1.1s
# 1490:	total: 3.15s	remaining: 1.07s
# 1500:	total: 3.17s	remaining: 1.05s
# 1510:	total: 3.19s	remaining: 1.03s
# 1520:	total: 3.21s	remaining: 1.01s
# 1530:	total: 3.23s	remaining: 989ms
# 1540:	total: 3.25s	remaining: 967ms
# 1550:	total: 3.27s	remaining: 946ms
# 1560:	total: 3.29s	remaining: 925ms
# 1570:	total: 3.31s	remaining: 903ms
# 1580:	total: 3.33s	remaining: 882ms
# 1590:	total: 3.35s	remaining: 860ms
# 1600:	total: 3.37s	remaining: 839ms
# 1610:	total: 3.38s	remaining: 817ms
# 1620:	total: 3.41s	remaining: 797ms
# 1630:	total: 3.43s	remaining: 776ms
# 1640:	total: 3.45s	remaining: 755ms
# 1650:	total: 3.47s	remaining: 734ms
# 1660:	total: 3.49s	remaining: 713ms
# 1670:	total: 3.51s	remaining: 692ms
# 1680:	total: 3.54s	remaining: 671ms
# 1690:	total: 3.56s	remaining: 650ms
# 1700:	total: 3.58s	remaining: 629ms
# 1710:	total: 3.6s	remaining: 608ms
# 1720:	total: 3.62s	remaining: 587ms
# 1730:	total: 3.64s	remaining: 566ms
# 1740:	total: 3.66s	remaining: 545ms
# 1750:	total: 3.69s	remaining: 524ms
# 1760:	total: 3.71s	remaining: 503ms
# 1770:	total: 3.73s	remaining: 482ms
# 1780:	total: 3.75s	remaining: 461ms
# 1790:	total: 3.77s	remaining: 440ms
# 1800:	total: 3.79s	remaining: 419ms
# 1810:	total: 3.81s	remaining: 398ms
# 1820:	total: 3.83s	remaining: 377ms
# 1830:	total: 3.85s	remaining: 356ms
# 1840:	total: 3.88s	remaining: 335ms
# 1850:	total: 3.9s	remaining: 314ms
# 1860:	total: 3.93s	remaining: 293ms
# 1870:	total: 3.95s	remaining: 272ms
# 1880:	total: 3.97s	remaining: 251ms
# 1890:	total: 3.99s	remaining: 230ms
# 1900:	total: 4.01s	remaining: 209ms
# 1910:	total: 4.04s	remaining: 188ms
# 1920:	total: 4.07s	remaining: 167ms
# 1930:	total: 4.09s	remaining: 146ms
# 1940:	total: 4.11s	remaining: 125ms
# 1950:	total: 4.13s	remaining: 104ms
# 1960:	total: 4.15s	remaining: 82.5ms
# 1970:	total: 4.17s	remaining: 61.3ms
# 1980:	total: 4.19s	remaining: 40.2ms
# 1990:	total: 4.21s	remaining: 19ms
# 1999:	total: 4.23s	remaining: 0us
# roc_auc_score:  0.8691860465116279
# confusion_matrix:  [[85  1]
#  [ 6 18]]
# accuracy_score:  0.9363636363636364

# %% [markdown]
# * лучше всех себя показала модель xgb

# %% [markdown]
# # Удаление выбросов

# %%
for i in train:
    max_ = train[i].max()
    quantile = train[i].quantile(0.99)
    print(i)
    print("max: ", max_)
    print("quantile 99: ", quantile)
    train[i] = train[i].drop(train[i].loc[train[i]>quantile].index)
# Out:
# ab
# max:  4.435374
# quantile 99:  2.067405589999999
# af
# max:  28688.18766
# quantile 99:  10150.88023619998
# ah
# max:  1910.123198
# quantile 99:  546.5820654
# am
# max:  630.51823
# quantile 99:  403.5895810999994
# ar
# max:  178.943634
# quantile 99:  33.199239599999885
# ax
# max:  38.27088
# quantile 99:  13.144718429999998
# ay
# max:  10.315851
# quantile 99:  0.22643228999999956
# az
# max:  38.971568
# quantile 99:  22.9370743
# bc
# max:  1463.693448
# quantile 99:  52.5272368599999
# bd
# max:  53060.59924
# quantile 99:  10320.462955399991
# bn
# max:  28.9542
# quantile 99:  28.248
# bp
# max:  2447.81055
# quantile 99:  976.4940900599984
# bq
# max:  344.644105
# quantile 99:  344.644105
# br
# max:  179250.2529
# quantile 99:  5245.003213999996
# bz
# max:  50092.4593
# quantile 99:  3098.786244429995
# cb
# max:  2271.436167
# quantile 99:  525.3320549749989
# cc
# max:  4.1030316
# quantile 99:  1.441057152599997
# cd
# max:  485.169816
# quantile 99:  262.1905745199999
# cf
# max:  200.967526
# quantile 99:  41.83008016999998
# ch
# max:  0.224074
# quantile 99:  0.06862315999999985
# cl
# max:  31.6881525
# quantile 99:  5.981508749999987
# cr
# max:  3.039675
# quantile 99:  1.6100069999999986
# cs
# max:  267.9428235
# quantile 99:  73.44364730999997
# cu
# max:  4.9515075
# quantile 99:  2.9418850799999987
# cw
# max:  64.521624
# quantile 99:  54.72490371999999
# da
# max:  210.33092
# quantile 99:  111.50475919999998
# de
# max:  2103.40519
# quantile 99:  1596.8513757999988
# df
# max:  16.155828
# quantile 99:  5.7326372999999995
# dh
# max:  1.060404
# quantile 99:  0.65736849
# di
# max:  1049.168078
# quantile 99:  494.9065956749983
# dl
# max:  326.2362
# quantile 99:  191.1448603999992
# dn
# max:  61.197632
# quantile 99:  49.62051127999998
# du
# max:  161.355315
# quantile 99:  20.16255185999988
# dv
# max:  25.19293
# quantile 99:  6.82335499999999
# dy
# max:  152.355164
# quantile 99:  97.31037567999998
# eb
# max:  94.95858
# quantile 99:  24.545149619999986
# ee
# max:  18.324926
# quantile 99:  9.786663349999984
# eg
# max:  30243.75878
# quantile 99:  6769.856470749973
# eh
# max:  42.569748
# quantile 99:  2.593974239999965
# el
# max:  109.125159
# quantile 99:  109.125159
# ep
# max:  1063.594578
# quantile 99:  310.02459942999997
# eu
# max:  6501.26448
# quantile 99:  743.8079666399994
# fc
# max:  3030.655824
# quantile 99:  705.6952089599985
# fd
# max:  1578.654237
# quantile 99:  34.38116699999987
# fe
# max:  143224.6823
# quantile 99:  69155.15940209982
# fi
# max:  35.851039
# quantile 99:  18.79706966999997
# fl
# max:  137.9327388
# quantile 99:  37.17236267919995
# fr
# max:  1244.22702
# quantile 99:  9.039987299999751
# fs
# max:  31.365763
# quantile 99:  1.607232899999998
# gb
# max:  135.781294
# quantile 99:  45.70621417999997
# ge
# max:  1497.351958
# quantile 99:  892.9907204399954
# gf
# max:  143790.0712
# quantile 99:  114539.62613699982
# gh
# max:  81.210825
# quantile 99:  62.13980695999998
# gi
# max:  191.194764
# quantile 99:  162.45099219999997
# gl
# max:  21.978
# quantile 99:  21.978
# class
# max:  1
# quantile 99:  1.0
# ej_freq
# max:  0.640194489465154
# quantile 99:  0.640194489465154

# %%
train.shape
# Out:
# (548, 57)

# %% [markdown]
# ##  train_test_split

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train.drop("class", axis=1), train["class"], test_size = 0.2)
x_train.shape, x_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((438, 56), (110, 56), (438,), (110,))

# %%
xgb_base(x_train, x_valid, y_train, y_valid)
# Out:
# [0]	dtrain-auc:0.94361	dvalid-auc:0.86861
# [10]	dtrain-auc:0.94913	dvalid-auc:0.88083
# [20]	dtrain-auc:0.97929	dvalid-auc:0.91667
# [30]	dtrain-auc:0.98876	dvalid-auc:0.91944
# [40]	dtrain-auc:0.98969	dvalid-auc:0.91833
# [50]	dtrain-auc:0.99133	dvalid-auc:0.91778
# [60]	dtrain-auc:0.99195	dvalid-auc:0.91556
# [62]	dtrain-auc:0.99233	dvalid-auc:0.91611

# %%
catboost_base(x_train, x_valid, y_train, y_valid)
# Out:
# 0:	total: 3.84ms	remaining: 7.67s
# 10:	total: 33ms	remaining: 5.97s
# 20:	total: 54ms	remaining: 5.09s
# 30:	total: 74.2ms	remaining: 4.71s
# 40:	total: 94.5ms	remaining: 4.51s
# 50:	total: 114ms	remaining: 4.36s
# 60:	total: 134ms	remaining: 4.26s
# 70:	total: 154ms	remaining: 4.19s
# 80:	total: 175ms	remaining: 4.14s
# 90:	total: 194ms	remaining: 4.08s
# 100:	total: 216ms	remaining: 4.06s
# 110:	total: 237ms	remaining: 4.03s
# 120:	total: 256ms	remaining: 3.98s
# 130:	total: 276ms	remaining: 3.94s
# 140:	total: 296ms	remaining: 3.9s
# 150:	total: 316ms	remaining: 3.87s
# 160:	total: 336ms	remaining: 3.83s
# 170:	total: 356ms	remaining: 3.81s
# 180:	total: 376ms	remaining: 3.77s
# 190:	total: 396ms	remaining: 3.75s
# 200:	total: 418ms	remaining: 3.74s
# 210:	total: 438ms	remaining: 3.72s
# 220:	total: 459ms	remaining: 3.69s
# 230:	total: 478ms	remaining: 3.66s
# 240:	total: 499ms	remaining: 3.64s
# 250:	total: 519ms	remaining: 3.62s
# 260:	total: 539ms	remaining: 3.59s
# 270:	total: 559ms	remaining: 3.57s
# 280:	total: 579ms	remaining: 3.54s
# 290:	total: 598ms	remaining: 3.51s
# 300:	total: 621ms	remaining: 3.5s
# 310:	total: 641ms	remaining: 3.48s
# 320:	total: 661ms	remaining: 3.46s
# 330:	total: 681ms	remaining: 3.43s
# 340:	total: 701ms	remaining: 3.41s
# 350:	total: 721ms	remaining: 3.39s
# 360:	total: 740ms	remaining: 3.36s
# 370:	total: 761ms	remaining: 3.34s
# 380:	total: 782ms	remaining: 3.32s
# 390:	total: 802ms	remaining: 3.3s
# 400:	total: 825ms	remaining: 3.29s
# 410:	total: 846ms	remaining: 3.27s
# 420:	total: 867ms	remaining: 3.25s
# 430:	total: 887ms	remaining: 3.23s
# 440:	total: 908ms	remaining: 3.21s
# 450:	total: 929ms	remaining: 3.19s
# 460:	total: 950ms	remaining: 3.17s
# 470:	total: 971ms	remaining: 3.15s
# 480:	total: 991ms	remaining: 3.13s
# 490:	total: 1.01s	remaining: 3.11s
# 500:	total: 1.03s	remaining: 3.09s
# 510:	total: 1.05s	remaining: 3.07s
# 520:	total: 1.07s	remaining: 3.05s
# 530:	total: 1.1s	remaining: 3.04s
# 540:	total: 1.12s	remaining: 3.02s
# 550:	total: 1.14s	remaining: 3s
# 560:	total: 1.16s	remaining: 2.97s
# 570:	total: 1.18s	remaining: 2.96s
# 580:	total: 1.21s	remaining: 2.94s
# 590:	total: 1.23s	remaining: 2.92s
# 600:	total: 1.25s	remaining: 2.9s
# 610:	total: 1.27s	remaining: 2.88s
# 620:	total: 1.29s	remaining: 2.86s
# 630:	total: 1.31s	remaining: 2.84s
# 640:	total: 1.33s	remaining: 2.81s
# 650:	total: 1.35s	remaining: 2.79s
# 660:	total: 1.37s	remaining: 2.77s
# 670:	total: 1.39s	remaining: 2.75s
# 680:	total: 1.41s	remaining: 2.73s
# 690:	total: 1.43s	remaining: 2.7s
# 700:	total: 1.45s	remaining: 2.68s
# 710:	total: 1.47s	remaining: 2.66s
# 720:	total: 1.49s	remaining: 2.64s
# 730:	total: 1.51s	remaining: 2.62s
# 740:	total: 1.53s	remaining: 2.6s
# 750:	total: 1.55s	remaining: 2.58s
# 760:	total: 1.57s	remaining: 2.56s
# 770:	total: 1.59s	remaining: 2.54s
# 780:	total: 1.61s	remaining: 2.52s
# 790:	total: 1.63s	remaining: 2.5s
# 800:	total: 1.66s	remaining: 2.48s
# 810:	total: 1.68s	remaining: 2.46s
# 820:	total: 1.7s	remaining: 2.44s
# 830:	total: 1.72s	remaining: 2.42s
# 840:	total: 1.74s	remaining: 2.4s
# 850:	total: 1.76s	remaining: 2.38s
# 860:	total: 1.78s	remaining: 2.36s
# 870:	total: 1.81s	remaining: 2.34s
# 880:	total: 1.83s	remaining: 2.32s
# 890:	total: 1.85s	remaining: 2.3s
# 900:	total: 1.87s	remaining: 2.28s
# 910:	total: 1.89s	remaining: 2.26s
# 920:	total: 1.91s	remaining: 2.24s
# 930:	total: 1.93s	remaining: 2.22s
# 940:	total: 1.95s	remaining: 2.2s
# 950:	total: 1.97s	remaining: 2.18s
# 960:	total: 1.99s	remaining: 2.16s
# 970:	total: 2.02s	remaining: 2.14s
# 980:	total: 2.04s	remaining: 2.12s
# 990:	total: 2.06s	remaining: 2.1s
# 1000:	total: 2.08s	remaining: 2.08s
# 1010:	total: 2.1s	remaining: 2.05s
# 1020:	total: 2.12s	remaining: 2.03s
# 1030:	total: 2.14s	remaining: 2.01s
# 1040:	total: 2.16s	remaining: 1.99s
# 1050:	total: 2.19s	remaining: 1.97s
# 1060:	total: 2.21s	remaining: 1.95s
# 1070:	total: 2.23s	remaining: 1.93s
# 1080:	total: 2.25s	remaining: 1.91s
# 1090:	total: 2.27s	remaining: 1.89s
# 1100:	total: 2.29s	remaining: 1.87s
# 1110:	total: 2.31s	remaining: 1.85s
# 1120:	total: 2.33s	remaining: 1.83s
# 1130:	total: 2.35s	remaining: 1.81s
# 1140:	total: 2.37s	remaining: 1.78s
# 1150:	total: 2.39s	remaining: 1.76s
# 1160:	total: 2.41s	remaining: 1.74s
# 1170:	total: 2.43s	remaining: 1.72s
# 1180:	total: 2.46s	remaining: 1.7s
# 1190:	total: 2.48s	remaining: 1.68s
# 1200:	total: 2.5s	remaining: 1.66s
# 1210:	total: 2.52s	remaining: 1.64s
# 1220:	total: 2.54s	remaining: 1.62s
# 1230:	total: 2.56s	remaining: 1.6s
# 1240:	total: 2.58s	remaining: 1.57s
# 1250:	total: 2.6s	remaining: 1.55s
# 1260:	total: 2.62s	remaining: 1.53s
# 1270:	total: 2.64s	remaining: 1.51s
# 1280:	total: 2.66s	remaining: 1.49s
# 1290:	total: 2.68s	remaining: 1.47s
# 1300:	total: 2.7s	remaining: 1.45s
# 1310:	total: 2.72s	remaining: 1.43s
# 1320:	total: 2.74s	remaining: 1.41s
# 1330:	total: 2.76s	remaining: 1.39s
# 1340:	total: 2.78s	remaining: 1.37s
# 1350:	total: 2.8s	remaining: 1.35s
# 1360:	total: 2.82s	remaining: 1.32s
# 1370:	total: 2.85s	remaining: 1.3s
# 1380:	total: 2.87s	remaining: 1.28s
# 1390:	total: 2.89s	remaining: 1.26s
# 1400:	total: 2.91s	remaining: 1.24s
# 1410:	total: 2.93s	remaining: 1.22s
# 1420:	total: 2.95s	remaining: 1.2s
# 1430:	total: 2.97s	remaining: 1.18s
# 1440:	total: 2.99s	remaining: 1.16s
# 1450:	total: 3.01s	remaining: 1.14s
# 1460:	total: 3.03s	remaining: 1.12s
# 1470:	total: 3.05s	remaining: 1.1s
# 1480:	total: 3.07s	remaining: 1.08s
# 1490:	total: 3.09s	remaining: 1.05s
# 1500:	total: 3.11s	remaining: 1.03s
# 1510:	total: 3.13s	remaining: 1.01s
# 1520:	total: 3.16s	remaining: 994ms
# 1530:	total: 3.18s	remaining: 974ms
# 1540:	total: 3.2s	remaining: 953ms
# 1550:	total: 3.22s	remaining: 933ms
# 1560:	total: 3.25s	remaining: 913ms
# 1570:	total: 3.27s	remaining: 892ms
# 1580:	total: 3.29s	remaining: 871ms
# 1590:	total: 3.31s	remaining: 850ms
# 1600:	total: 3.33s	remaining: 830ms
# 1610:	total: 3.35s	remaining: 809ms
# 1620:	total: 3.37s	remaining: 788ms
# 1630:	total: 3.39s	remaining: 768ms
# 1640:	total: 3.41s	remaining: 747ms
# 1650:	total: 3.43s	remaining: 726ms
# 1660:	total: 3.45s	remaining: 705ms
# 1670:	total: 3.48s	remaining: 684ms
# 1680:	total: 3.5s	remaining: 663ms
# 1690:	total: 3.52s	remaining: 642ms
# 1700:	total: 3.54s	remaining: 622ms
# 1710:	total: 3.56s	remaining: 601ms
# 1720:	total: 3.58s	remaining: 580ms
# 1730:	total: 3.6s	remaining: 559ms
# 1740:	total: 3.62s	remaining: 539ms
# 1750:	total: 3.64s	remaining: 518ms
# 1760:	total: 3.66s	remaining: 497ms
# 1770:	total: 3.68s	remaining: 476ms
# 1780:	total: 3.71s	remaining: 456ms
# 1790:	total: 3.73s	remaining: 435ms
# 1800:	total: 3.75s	remaining: 414ms
# 1810:	total: 3.77s	remaining: 393ms
# 1820:	total: 3.78s	remaining: 372ms
# 1830:	total: 3.8s	remaining: 351ms
# 1840:	total: 3.83s	remaining: 330ms
# 1850:	total: 3.85s	remaining: 310ms
# 1860:	total: 3.87s	remaining: 289ms
# 1870:	total: 3.89s	remaining: 268ms
# 1880:	total: 3.91s	remaining: 247ms
# 1890:	total: 3.93s	remaining: 227ms
# 1900:	total: 3.95s	remaining: 206ms
# 1910:	total: 3.97s	remaining: 185ms
# 1920:	total: 4s	remaining: 164ms
# 1930:	total: 4.02s	remaining: 144ms
# 1940:	total: 4.04s	remaining: 123ms
# 1950:	total: 4.06s	remaining: 102ms
# 1960:	total: 4.08s	remaining: 81.2ms
# 1970:	total: 4.1s	remaining: 60.4ms
# 1980:	total: 4.12s	remaining: 39.5ms
# 1990:	total: 4.14s	remaining: 18.7ms
# 1999:	total: 4.16s	remaining: 0us
# roc_auc_score:  0.8766720171214553
# confusion_matrix:  [[84  5]
#  [ 4 17]]
# accuracy_score:  0.9181818181818182

# %% [markdown]
# * Уберу признаки которые визуально плохо разделимы
# * gi, dl, dh, fs, dy, cu, ay, br

# %%
train_new = train.drop(["gi", "dl", "dh", "fs", "dy", "cu", "ay", "br"], axis=1)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train_new.drop("class", axis=1), train_new["class"], test_size = 0.2)
x_train.shape, x_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((438, 48), (110, 48), (438,), (110,))

# %%
xgb_base(x_train, x_valid, y_train, y_valid)
# Out:
# [0]	dtrain-auc:0.94464	dvalid-auc:0.89034
# [10]	dtrain-auc:0.97606	dvalid-auc:0.89721
# [20]	dtrain-auc:0.97872	dvalid-auc:0.90339
# [30]	dtrain-auc:0.98046	dvalid-auc:0.89995
# [40]	dtrain-auc:0.98859	dvalid-auc:0.91117
# [50]	dtrain-auc:0.99429	dvalid-auc:0.91575
# [60]	dtrain-auc:0.99615	dvalid-auc:0.91621
# [70]	dtrain-auc:0.99742	dvalid-auc:0.91529
# [80]	dtrain-auc:0.99869	dvalid-auc:0.91712
# [90]	dtrain-auc:0.99898	dvalid-auc:0.91941
# [100]	dtrain-auc:0.99920	dvalid-auc:0.91896
# [110]	dtrain-auc:0.99945	dvalid-auc:0.91941
# [116]	dtrain-auc:0.99953	dvalid-auc:0.91941

# %%
catboost_base(x_train, x_valid, y_train, y_valid)
# Out:
# 0:	total: 3.29ms	remaining: 6.59s
# 10:	total: 36.3ms	remaining: 6.56s
# 20:	total: 64.9ms	remaining: 6.12s
# 30:	total: 102ms	remaining: 6.49s
# 40:	total: 123ms	remaining: 5.87s
# 50:	total: 142ms	remaining: 5.43s
# 60:	total: 161ms	remaining: 5.12s
# 70:	total: 181ms	remaining: 4.91s
# 80:	total: 204ms	remaining: 4.82s
# 90:	total: 223ms	remaining: 4.68s
# 100:	total: 243ms	remaining: 4.57s
# 110:	total: 262ms	remaining: 4.46s
# 120:	total: 281ms	remaining: 4.37s
# 130:	total: 302ms	remaining: 4.32s
# 140:	total: 324ms	remaining: 4.26s
# 150:	total: 345ms	remaining: 4.22s
# 160:	total: 364ms	remaining: 4.16s
# 170:	total: 384ms	remaining: 4.11s
# 180:	total: 410ms	remaining: 4.12s
# 190:	total: 431ms	remaining: 4.08s
# 200:	total: 451ms	remaining: 4.04s
# 210:	total: 472ms	remaining: 4s
# 220:	total: 492ms	remaining: 3.96s
# 230:	total: 512ms	remaining: 3.92s
# 240:	total: 533ms	remaining: 3.89s
# 250:	total: 553ms	remaining: 3.85s
# 260:	total: 574ms	remaining: 3.83s
# 270:	total: 600ms	remaining: 3.83s
# 280:	total: 623ms	remaining: 3.81s
# 290:	total: 643ms	remaining: 3.78s
# 300:	total: 664ms	remaining: 3.75s
# 310:	total: 685ms	remaining: 3.72s
# 320:	total: 706ms	remaining: 3.69s
# 330:	total: 725ms	remaining: 3.66s
# 340:	total: 746ms	remaining: 3.63s
# 350:	total: 767ms	remaining: 3.6s
# 360:	total: 790ms	remaining: 3.59s
# 370:	total: 808ms	remaining: 3.55s
# 380:	total: 827ms	remaining: 3.51s
# 390:	total: 845ms	remaining: 3.48s
# 400:	total: 864ms	remaining: 3.44s
# 410:	total: 883ms	remaining: 3.41s
# 420:	total: 901ms	remaining: 3.38s
# 430:	total: 919ms	remaining: 3.35s
# 440:	total: 940ms	remaining: 3.32s
# 450:	total: 964ms	remaining: 3.31s
# 460:	total: 989ms	remaining: 3.3s
# 470:	total: 1.01s	remaining: 3.27s
# 480:	total: 1.03s	remaining: 3.25s
# 490:	total: 1.05s	remaining: 3.23s
# 500:	total: 1.07s	remaining: 3.2s
# 510:	total: 1.09s	remaining: 3.18s
# 520:	total: 1.11s	remaining: 3.15s
# 530:	total: 1.13s	remaining: 3.13s
# 540:	total: 1.15s	remaining: 3.11s
# 550:	total: 1.17s	remaining: 3.08s
# 560:	total: 1.19s	remaining: 3.06s
# 570:	total: 1.22s	remaining: 3.04s
# 580:	total: 1.24s	remaining: 3.02s
# 590:	total: 1.26s	remaining: 3s
# 600:	total: 1.28s	remaining: 2.98s
# 610:	total: 1.3s	remaining: 2.96s
# 620:	total: 1.33s	remaining: 2.96s
# 630:	total: 1.35s	remaining: 2.94s
# 640:	total: 1.38s	remaining: 2.92s
# 650:	total: 1.4s	remaining: 2.9s
# 660:	total: 1.42s	remaining: 2.88s
# 670:	total: 1.44s	remaining: 2.85s
# 680:	total: 1.46s	remaining: 2.83s
# 690:	total: 1.48s	remaining: 2.81s
# 700:	total: 1.5s	remaining: 2.78s
# 710:	total: 1.52s	remaining: 2.76s
# 720:	total: 1.54s	remaining: 2.74s
# 730:	total: 1.56s	remaining: 2.71s
# 740:	total: 1.58s	remaining: 2.69s
# 750:	total: 1.61s	remaining: 2.67s
# 760:	total: 1.63s	remaining: 2.65s
# 770:	total: 1.65s	remaining: 2.62s
# 780:	total: 1.66s	remaining: 2.6s
# 790:	total: 1.68s	remaining: 2.57s
# 800:	total: 1.7s	remaining: 2.55s
# 810:	total: 1.72s	remaining: 2.52s
# 820:	total: 1.74s	remaining: 2.5s
# 830:	total: 1.76s	remaining: 2.48s
# 840:	total: 1.78s	remaining: 2.46s
# 850:	total: 1.81s	remaining: 2.44s
# 860:	total: 1.83s	remaining: 2.42s
# 870:	total: 1.86s	remaining: 2.41s
# 880:	total: 1.88s	remaining: 2.38s
# 890:	total: 1.9s	remaining: 2.36s
# 900:	total: 1.92s	remaining: 2.34s
# 910:	total: 1.94s	remaining: 2.32s
# 920:	total: 1.96s	remaining: 2.29s
# 930:	total: 1.98s	remaining: 2.27s
# 940:	total: 2s	remaining: 2.25s
# 950:	total: 2.02s	remaining: 2.23s
# 960:	total: 2.04s	remaining: 2.21s
# 970:	total: 2.06s	remaining: 2.18s
# 980:	total: 2.08s	remaining: 2.16s
# 990:	total: 2.1s	remaining: 2.14s
# 1000:	total: 2.12s	remaining: 2.12s
# 1010:	total: 2.14s	remaining: 2.1s
# 1020:	total: 2.16s	remaining: 2.07s
# 1030:	total: 2.18s	remaining: 2.05s
# 1040:	total: 2.2s	remaining: 2.03s
# 1050:	total: 2.22s	remaining: 2.01s
# 1060:	total: 2.25s	remaining: 1.99s
# 1070:	total: 2.27s	remaining: 1.97s
# 1080:	total: 2.28s	remaining: 1.94s
# 1090:	total: 2.3s	remaining: 1.92s
# 1100:	total: 2.32s	remaining: 1.9s
# 1110:	total: 2.34s	remaining: 1.87s
# 1120:	total: 2.36s	remaining: 1.85s
# 1130:	total: 2.38s	remaining: 1.83s
# 1140:	total: 2.4s	remaining: 1.81s
# 1150:	total: 2.42s	remaining: 1.78s
# 1160:	total: 2.44s	remaining: 1.76s
# 1170:	total: 2.45s	remaining: 1.74s
# 1180:	total: 2.47s	remaining: 1.71s
# 1190:	total: 2.49s	remaining: 1.69s
# 1200:	total: 2.51s	remaining: 1.67s
# 1210:	total: 2.53s	remaining: 1.65s
# 1220:	total: 2.55s	remaining: 1.62s
# 1230:	total: 2.56s	remaining: 1.6s
# 1240:	total: 2.58s	remaining: 1.58s
# 1250:	total: 2.6s	remaining: 1.56s
# 1260:	total: 2.62s	remaining: 1.54s
# 1270:	total: 2.64s	remaining: 1.51s
# 1280:	total: 2.66s	remaining: 1.49s
# 1290:	total: 2.68s	remaining: 1.47s
# 1300:	total: 2.7s	remaining: 1.45s
# 1310:	total: 2.72s	remaining: 1.43s
# 1320:	total: 2.74s	remaining: 1.41s
# 1330:	total: 2.76s	remaining: 1.39s
# 1340:	total: 2.77s	remaining: 1.36s
# 1350:	total: 2.79s	remaining: 1.34s
# 1360:	total: 2.81s	remaining: 1.32s
# 1370:	total: 2.83s	remaining: 1.3s
# 1380:	total: 2.85s	remaining: 1.28s
# 1390:	total: 2.87s	remaining: 1.26s
# 1400:	total: 2.89s	remaining: 1.23s
# 1410:	total: 2.9s	remaining: 1.21s
# 1420:	total: 2.92s	remaining: 1.19s
# 1430:	total: 2.94s	remaining: 1.17s
# 1440:	total: 2.96s	remaining: 1.15s
# 1450:	total: 2.98s	remaining: 1.13s
# 1460:	total: 3s	remaining: 1.11s
# 1470:	total: 3.02s	remaining: 1.08s
# 1480:	total: 3.04s	remaining: 1.06s
# 1490:	total: 3.05s	remaining: 1.04s
# 1500:	total: 3.07s	remaining: 1.02s
# 1510:	total: 3.09s	remaining: 1s
# 1520:	total: 3.11s	remaining: 980ms
# 1530:	total: 3.13s	remaining: 958ms
# 1540:	total: 3.15s	remaining: 937ms
# 1550:	total: 3.16s	remaining: 916ms
# 1560:	total: 3.18s	remaining: 895ms
# 1570:	total: 3.2s	remaining: 875ms
# 1580:	total: 3.22s	remaining: 854ms
# 1590:	total: 3.24s	remaining: 833ms
# 1600:	total: 3.26s	remaining: 812ms
# 1610:	total: 3.28s	remaining: 791ms
# 1620:	total: 3.29s	remaining: 770ms
# 1630:	total: 3.31s	remaining: 750ms
# 1640:	total: 3.33s	remaining: 729ms
# 1650:	total: 3.35s	remaining: 708ms
# 1660:	total: 3.37s	remaining: 687ms
# 1670:	total: 3.38s	remaining: 667ms
# 1680:	total: 3.4s	remaining: 646ms
# 1690:	total: 3.42s	remaining: 625ms
# 1700:	total: 3.44s	remaining: 605ms
# 1710:	total: 3.46s	remaining: 584ms
# 1720:	total: 3.48s	remaining: 564ms
# 1730:	total: 3.5s	remaining: 543ms
# 1740:	total: 3.51s	remaining: 523ms
# 1750:	total: 3.53s	remaining: 502ms
# 1760:	total: 3.55s	remaining: 482ms
# 1770:	total: 3.57s	remaining: 461ms
# 1780:	total: 3.59s	remaining: 441ms
# 1790:	total: 3.6s	remaining: 421ms
# 1800:	total: 3.63s	remaining: 401ms
# 1810:	total: 3.65s	remaining: 380ms
# 1820:	total: 3.66s	remaining: 360ms
# 1830:	total: 3.68s	remaining: 340ms
# 1840:	total: 3.7s	remaining: 320ms
# 1850:	total: 3.72s	remaining: 299ms
# 1860:	total: 3.74s	remaining: 279ms
# 1870:	total: 3.76s	remaining: 259ms
# 1880:	total: 3.77s	remaining: 239ms
# 1890:	total: 3.79s	remaining: 219ms
# 1900:	total: 3.81s	remaining: 199ms
# 1910:	total: 3.83s	remaining: 178ms
# 1920:	total: 3.85s	remaining: 158ms
# 1930:	total: 3.87s	remaining: 138ms
# 1940:	total: 3.89s	remaining: 118ms
# 1950:	total: 3.91s	remaining: 98.1ms
# 1960:	total: 3.92s	remaining: 78.1ms
# 1970:	total: 3.94s	remaining: 58ms
# 1980:	total: 3.96s	remaining: 38ms
# 1990:	total: 3.98s	remaining: 18ms
# 1999:	total: 4s	remaining: 0us
# roc_auc_score:  0.7692307692307692
# confusion_matrix:  [[84  0]
#  [12 14]]
# accuracy_score:  0.8909090909090909

# %% [markdown]
# * После удаления стало хуже
#
# * Обучение на признаках которые показали наибольшую нелинейную зависимость
# 'du', 'cr', 'di', 'eh', 'gl', 'fd ', 'bc', 'fl', 'ab', 'bq', 'cc', 'da','af', 'ee', 'cd ', 'de', 'dh', 'dy', 'fe', 'el'

# %%
train_new = train[['du', 'cr', 'di', 'eh', 'gl', 'fd ', 'bc', 'fl', 'ab', 'bq', 'cc', 'da',
        'af', 'ee', 'cd ', 'de', 'dh', 'dy', 'fe', 'el', "class"]]
train_new.shape
# Out:
# (548, 21)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train_new.drop("class", axis=1), train_new["class"], test_size = 0.2)
x_train.shape, x_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((438, 20), (110, 20), (438,), (110,))

# %%
xgb_base(x_train, x_valid, y_train, y_valid)
# Out:
# [0]	dtrain-auc:0.96581	dvalid-auc:0.88490
# [10]	dtrain-auc:0.97811	dvalid-auc:0.87247
# [20]	dtrain-auc:0.98157	dvalid-auc:0.89358
# [30]	dtrain-auc:0.98239	dvalid-auc:0.89329
# [40]	dtrain-auc:0.98347	dvalid-auc:0.89589
# [50]	dtrain-auc:0.98500	dvalid-auc:0.90110
# [60]	dtrain-auc:0.98610	dvalid-auc:0.90341
# [70]	dtrain-auc:0.98609	dvalid-auc:0.91990
# [80]	dtrain-auc:0.99262	dvalid-auc:0.91874
# [90]	dtrain-auc:0.99533	dvalid-auc:0.91816
# [98]	dtrain-auc:0.99644	dvalid-auc:0.91643

# %%
catboost_base(x_train, x_valid, y_train, y_valid)
# Out:
# 0:	total: 2.61ms	remaining: 5.21s
# 10:	total: 26.4ms	remaining: 4.77s
# 20:	total: 52.8ms	remaining: 4.98s
# 30:	total: 77.3ms	remaining: 4.91s
# 40:	total: 94.2ms	remaining: 4.5s
# 50:	total: 111ms	remaining: 4.23s
# 60:	total: 127ms	remaining: 4.03s
# 70:	total: 142ms	remaining: 3.86s
# 80:	total: 159ms	remaining: 3.76s
# 90:	total: 175ms	remaining: 3.67s
# 100:	total: 192ms	remaining: 3.62s
# 110:	total: 209ms	remaining: 3.56s
# 120:	total: 225ms	remaining: 3.5s
# 130:	total: 241ms	remaining: 3.44s
# 140:	total: 257ms	remaining: 3.39s
# 150:	total: 273ms	remaining: 3.34s
# 160:	total: 290ms	remaining: 3.31s
# 170:	total: 306ms	remaining: 3.27s
# 180:	total: 322ms	remaining: 3.24s
# 190:	total: 338ms	remaining: 3.2s
# 200:	total: 353ms	remaining: 3.16s
# 210:	total: 368ms	remaining: 3.12s
# 220:	total: 396ms	remaining: 3.19s
# 230:	total: 413ms	remaining: 3.16s
# 240:	total: 431ms	remaining: 3.15s
# 250:	total: 447ms	remaining: 3.11s
# 260:	total: 462ms	remaining: 3.08s
# 270:	total: 479ms	remaining: 3.06s
# 280:	total: 494ms	remaining: 3.02s
# 290:	total: 509ms	remaining: 2.99s
# 300:	total: 525ms	remaining: 2.96s
# 310:	total: 540ms	remaining: 2.93s
# 320:	total: 558ms	remaining: 2.92s
# 330:	total: 573ms	remaining: 2.89s
# 340:	total: 594ms	remaining: 2.89s
# 350:	total: 613ms	remaining: 2.88s
# 360:	total: 630ms	remaining: 2.86s
# 370:	total: 644ms	remaining: 2.83s
# 380:	total: 660ms	remaining: 2.8s
# 390:	total: 674ms	remaining: 2.77s
# 400:	total: 690ms	remaining: 2.75s
# 410:	total: 707ms	remaining: 2.73s
# 420:	total: 724ms	remaining: 2.71s
# 430:	total: 741ms	remaining: 2.7s
# 440:	total: 758ms	remaining: 2.68s
# 450:	total: 779ms	remaining: 2.68s
# 460:	total: 795ms	remaining: 2.65s
# 470:	total: 811ms	remaining: 2.63s
# 480:	total: 826ms	remaining: 2.61s
# 490:	total: 842ms	remaining: 2.59s
# 500:	total: 857ms	remaining: 2.56s
# 510:	total: 873ms	remaining: 2.54s
# 520:	total: 889ms	remaining: 2.52s
# 530:	total: 904ms	remaining: 2.5s
# 540:	total: 920ms	remaining: 2.48s
# 550:	total: 936ms	remaining: 2.46s
# 560:	total: 952ms	remaining: 2.44s
# 570:	total: 969ms	remaining: 2.42s
# 580:	total: 985ms	remaining: 2.4s
# 590:	total: 1s	remaining: 2.39s
# 600:	total: 1.02s	remaining: 2.37s
# 610:	total: 1.03s	remaining: 2.35s
# 620:	total: 1.05s	remaining: 2.34s
# 630:	total: 1.07s	remaining: 2.33s
# 640:	total: 1.09s	remaining: 2.31s
# 650:	total: 1.11s	remaining: 2.29s
# 660:	total: 1.13s	remaining: 2.28s
# 670:	total: 1.14s	remaining: 2.26s
# 680:	total: 1.16s	remaining: 2.25s
# 690:	total: 1.18s	remaining: 2.23s
# 700:	total: 1.19s	remaining: 2.21s
# 710:	total: 1.21s	remaining: 2.19s
# 720:	total: 1.22s	remaining: 2.17s
# 730:	total: 1.24s	remaining: 2.15s
# 740:	total: 1.25s	remaining: 2.13s
# 750:	total: 1.27s	remaining: 2.11s
# 760:	total: 1.28s	remaining: 2.09s
# 770:	total: 1.3s	remaining: 2.07s
# 780:	total: 1.31s	remaining: 2.05s
# 790:	total: 1.33s	remaining: 2.03s
# 800:	total: 1.34s	remaining: 2.01s
# 810:	total: 1.36s	remaining: 2s
# 820:	total: 1.38s	remaining: 1.98s
# 830:	total: 1.39s	remaining: 1.96s
# 840:	total: 1.41s	remaining: 1.94s
# 850:	total: 1.42s	remaining: 1.92s
# 860:	total: 1.44s	remaining: 1.9s
# 870:	total: 1.45s	remaining: 1.88s
# 880:	total: 1.47s	remaining: 1.86s
# 890:	total: 1.48s	remaining: 1.84s
# 900:	total: 1.5s	remaining: 1.82s
# 910:	total: 1.51s	remaining: 1.8s
# 920:	total: 1.52s	remaining: 1.78s
# 930:	total: 1.54s	remaining: 1.77s
# 940:	total: 1.56s	remaining: 1.75s
# 950:	total: 1.57s	remaining: 1.73s
# 960:	total: 1.59s	remaining: 1.72s
# 970:	total: 1.6s	remaining: 1.7s
# 980:	total: 1.61s	remaining: 1.68s
# 990:	total: 1.63s	remaining: 1.66s
# 1000:	total: 1.65s	remaining: 1.64s
# 1010:	total: 1.66s	remaining: 1.63s
# 1020:	total: 1.68s	remaining: 1.61s
# 1030:	total: 1.69s	remaining: 1.59s
# 1040:	total: 1.71s	remaining: 1.57s
# 1050:	total: 1.73s	remaining: 1.56s
# 1060:	total: 1.75s	remaining: 1.54s
# 1070:	total: 1.76s	remaining: 1.53s
# 1080:	total: 1.78s	remaining: 1.51s
# 1090:	total: 1.79s	remaining: 1.49s
# 1100:	total: 1.81s	remaining: 1.48s
# 1110:	total: 1.82s	remaining: 1.46s
# 1120:	total: 1.84s	remaining: 1.44s
# 1130:	total: 1.85s	remaining: 1.42s
# 1140:	total: 1.87s	remaining: 1.41s
# 1150:	total: 1.88s	remaining: 1.39s
# 1160:	total: 1.9s	remaining: 1.37s
# 1170:	total: 1.91s	remaining: 1.35s
# 1180:	total: 1.93s	remaining: 1.34s
# 1190:	total: 1.95s	remaining: 1.32s
# 1200:	total: 1.96s	remaining: 1.3s
# 1210:	total: 1.98s	remaining: 1.29s
# 1220:	total: 1.99s	remaining: 1.27s
# 1230:	total: 2.01s	remaining: 1.25s
# 1240:	total: 2.02s	remaining: 1.24s
# 1250:	total: 2.04s	remaining: 1.22s
# 1260:	total: 2.05s	remaining: 1.2s
# 1270:	total: 2.07s	remaining: 1.19s
# 1280:	total: 2.08s	remaining: 1.17s
# 1290:	total: 2.1s	remaining: 1.15s
# 1300:	total: 2.12s	remaining: 1.14s
# 1310:	total: 2.13s	remaining: 1.12s
# 1320:	total: 2.15s	remaining: 1.1s
# 1330:	total: 2.16s	remaining: 1.09s
# 1340:	total: 2.18s	remaining: 1.07s
# 1350:	total: 2.19s	remaining: 1.05s
# 1360:	total: 2.21s	remaining: 1.04s
# 1370:	total: 2.22s	remaining: 1.02s
# 1380:	total: 2.24s	remaining: 1s
# 1390:	total: 2.25s	remaining: 986ms
# 1400:	total: 2.27s	remaining: 969ms
# 1410:	total: 2.28s	remaining: 953ms
# 1420:	total: 2.3s	remaining: 937ms
# 1430:	total: 2.31s	remaining: 921ms
# 1440:	total: 2.33s	remaining: 904ms
# 1450:	total: 2.34s	remaining: 887ms
# 1460:	total: 2.36s	remaining: 871ms
# 1470:	total: 2.38s	remaining: 855ms
# 1480:	total: 2.39s	remaining: 838ms
# 1490:	total: 2.41s	remaining: 822ms
# 1500:	total: 2.42s	remaining: 805ms
# 1510:	total: 2.44s	remaining: 788ms
# 1520:	total: 2.45s	remaining: 771ms
# 1530:	total: 2.46s	remaining: 755ms
# 1540:	total: 2.48s	remaining: 739ms
# 1550:	total: 2.5s	remaining: 723ms
# 1560:	total: 2.51s	remaining: 707ms
# 1570:	total: 2.53s	remaining: 691ms
# 1580:	total: 2.54s	remaining: 675ms
# 1590:	total: 2.56s	remaining: 658ms
# 1600:	total: 2.58s	remaining: 642ms
# 1610:	total: 2.59s	remaining: 625ms
# 1620:	total: 2.6s	remaining: 609ms
# 1630:	total: 2.62s	remaining: 592ms
# 1640:	total: 2.63s	remaining: 576ms
# 1650:	total: 2.65s	remaining: 560ms
# 1660:	total: 2.66s	remaining: 543ms
# 1670:	total: 2.68s	remaining: 527ms
# 1680:	total: 2.69s	remaining: 511ms
# 1690:	total: 2.71s	remaining: 495ms
# 1700:	total: 2.72s	remaining: 478ms
# 1710:	total: 2.73s	remaining: 462ms
# 1720:	total: 2.75s	remaining: 446ms
# 1730:	total: 2.76s	remaining: 429ms
# 1740:	total: 2.78s	remaining: 413ms
# 1750:	total: 2.79s	remaining: 397ms
# 1760:	total: 2.81s	remaining: 381ms
# 1770:	total: 2.82s	remaining: 365ms
# 1780:	total: 2.83s	remaining: 348ms
# 1790:	total: 2.85s	remaining: 332ms
# 1800:	total: 2.86s	remaining: 316ms
# 1810:	total: 2.88s	remaining: 300ms
# 1820:	total: 2.89s	remaining: 284ms
# 1830:	total: 2.91s	remaining: 268ms
# 1840:	total: 2.92s	remaining: 252ms
# 1850:	total: 2.94s	remaining: 236ms
# 1860:	total: 2.95s	remaining: 220ms
# 1870:	total: 2.96s	remaining: 204ms
# 1880:	total: 2.98s	remaining: 188ms
# 1890:	total: 2.99s	remaining: 173ms
# 1900:	total: 3.01s	remaining: 157ms
# 1910:	total: 3.02s	remaining: 141ms
# 1920:	total: 3.04s	remaining: 125ms
# 1930:	total: 3.05s	remaining: 109ms
# 1940:	total: 3.07s	remaining: 93.2ms
# 1950:	total: 3.08s	remaining: 77.4ms
# 1960:	total: 3.1s	remaining: 61.6ms
# 1970:	total: 3.11s	remaining: 45.8ms
# 1980:	total: 3.13s	remaining: 30ms
# 1990:	total: 3.14s	remaining: 14.2ms
# 1999:	total: 3.15s	remaining: 0us
# roc_auc_score:  0.7356853672643145
# confusion_matrix:  [[86  5]
#  [ 9 10]]
# accuracy_score:  0.8727272727272727

# %% [markdown]
# * Cтало явно еще хуже
# * Обучение на признаках которые показали хорошую разделяющую способность по метрике gini
# * bq, ab, du, af, fl, bn, bc, cd, cr, gl, da, de

# %%
train.columns
# Out:
# Index(['ab', 'af', 'ah', 'am', 'ar', 'ax', 'ay', 'az', 'bc', 'bd ', 'bn', 'bp',
#        'bq', 'br', 'bz', 'cb', 'cc', 'cd ', 'cf', 'ch', 'cl', 'cr', 'cs', 'cu',
#        'cw ', 'da', 'de', 'df', 'dh', 'di', 'dl', 'dn', 'du', 'dv', 'dy', 'eb',
#        'ee', 'eg', 'eh', 'el', 'ep', 'eu', 'fc', 'fd ', 'fe', 'fi', 'fl', 'fr',
#        'fs', 'gb', 'ge', 'gf', 'gh', 'gi', 'gl', 'class', 'ej_freq'],
#       dtype='object')

# %%
train_new = train[["bq", "ab", "du", "af", "fl", "bn", "bc", "cd ", "cr", "gl", "da", "de", "class"]]

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train_new.drop("class", axis=1), train_new["class"], test_size = 0.2)
x_train.shape, x_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((438, 12), (110, 12), (438,), (110,))

# %%
xgb_base(x_train, x_valid, y_train, y_valid)
# Out:
# [0]	dtrain-auc:0.94899	dvalid-auc:0.84163
# [10]	dtrain-auc:0.96376	dvalid-auc:0.85340
# [20]	dtrain-auc:0.97064	dvalid-auc:0.85179
# [26]	dtrain-auc:0.97154	dvalid-auc:0.85045

# %%
catboost_base(x_train, x_valid, y_train, y_valid)
# Out:
# roc_auc_score:  0.7212413055109685
# confusion_matrix:  [[86  3]
#  [11 10]]
# accuracy_score:  0.8727272727272727
